# %% [markdown]
# <a href="https://colab.research.google.com/github/Leorodr501/EDA-Assignment/blob/master/Homework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_clean.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  pclass  survived  \
# 0           1     1.0       1.0
# 1           2     1.0       1.0
# 2           3     1.0       0.0
# 3           4     1.0       0.0
# 4           5     1.0       0.0
#
#                                               name     sex      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000    0.0
# 1                   Allison, Master. Hudson Trevor    male   0.9167    1.0
# 2                     Allison, Miss. Helen Loraine  female   2.0000    1.0
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000    1.0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000    1.0
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0    0.0   24160  211.3375       B5        S    2    NaN
# 1    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'pclass', 'survived', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
#        'home.dest', 'has_cabin_number'],
#       dtype='object')

# %%
df.columns = ['Unnamed: 0', 'pclass', 'survived', 'name', 'sex', 'age', 'sibsp',
       'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
       'home.dest', 'cabin_number']

# %%
df.head()
# Out:
#    Unnamed: 0  pclass  survived  \
# 0           1     1.0       1.0
# 1           2     1.0       1.0
# 2           3     1.0       0.0
# 3           4     1.0       0.0
# 4           5     1.0       0.0
#
#                                               name     sex      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000    0.0
# 1                   Allison, Master. Hudson Trevor    male   0.9167    1.0
# 2                     Allison, Miss. Helen Loraine  female   2.0000    1.0
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000    1.0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000    1.0
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0    0.0   24160  211.3375       B5        S    2    NaN
# 1    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# ...

# %%
df.isnull().sum(axis = 0)
# Out:
# Unnamed: 0         0
# pclass             1
# survived           1
# name               1
# sex                1
# age                0
# sibsp              1
# parch              1
# ticket             1
# fare               2
# cabin           1015
# embarked           0
# boat             824
# body            1189
# home.dest        565
# cabin_number       0
# dtype: int64

# %%
df['Last_Name'] = df['name'].str.split(",").str[0]
df['First_Name'] = df['name'].str.split(",").str[1]

# %%
df.head()
# Out:
#    Unnamed: 0  pclass  survived  \
# 0           1     1.0       1.0
# 1           2     1.0       1.0
# 2           3     1.0       0.0
# 3           4     1.0       0.0
# 4           5     1.0       0.0
#
#                                               name     sex      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.0000    0.0
# 1                   Allison, Master. Hudson Trevor    male   0.9167    1.0
# 2                     Allison, Miss. Helen Loraine  female   2.0000    1.0
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.0000    1.0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000    1.0
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0    0.0   24160  211.3375       B5        S    2    NaN
# 1    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# ...

# %%
del df['name']

# %%
df.head()
# Out:
#    Unnamed: 0  pclass  survived     sex      age  sibsp  parch  ticket  \
# 0           1     1.0       1.0  female  29.0000    0.0    0.0   24160
# 1           2     1.0       1.0    male   0.9167    1.0    2.0  113781
# 2           3     1.0       0.0  female   2.0000    1.0    2.0  113781
# 3           4     1.0       0.0    male  30.0000    1.0    2.0  113781
# 4           5     1.0       0.0  female  25.0000    1.0    2.0  113781
#
#        fare    cabin embarked boat   body                        home.dest  \
# 0  211.3375       B5        S    2    NaN                     St Louis, MO
# 1  151.5500  C22 C26        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2  151.5500  C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3  151.5500  C22 C26        S  NaN  135.0  Montreal, PQ / Chesterville, ON
# 4  151.5500  C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
#
#    cabin_number Last_Name                               First_Name
# ...

# %%
df.groupby("Last_Name").count()
# Out:
#                   Unnamed: 0  pclass  survived  sex  age  sibsp  parch  \
# Last_Name
# Abbing                     1       1         1    1    1      1      1
# Abbott                     3       3         3    3    3      3      3
# Abelseth                   2       2         2    2    2      2      2
# Abelson                    2       2         2    2    2      2      2
# Abrahamsson                1       1         1    1    1      1      1
# Abrahim                    1       1         1    1    1      1      1
# Adahl                      1       1         1    1    1      1      1
# Adams                      1       1         1    1    1      1      1
# Ahlin                      1       1         1    1    1      1      1
# Aks                        2       2         2    2    2      2      2
# Albimona                   1       1         1    1    1      1      1
# Aldworth                   1       1         1    1    1      1      1
# ...

# %%
df.groupby(["Last_Name"])["survived"].count()
# Out:
# Last_Name
# Abbing               1
# Abbott               3
# Abelseth             2
# Abelson              2
# Abrahamsson          1
# Abrahim              1
# Adahl                1
# Adams                1
# Ahlin                1
# Aks                  2
# Albimona             1
# Aldworth             1
# Alexander            1
# Alhomaki             1
# Ali                  2
# Allen                2
# Allison              4
# Allum                1
# Andersen             1
# Andersen-Jensen      1
# Anderson             1
# Andersson           11
# Andreasson           1
# Andrew               2
# Andrews              2
# Angheloff            1
# Angle                2
# Appleton             1
# Arnold-Franchi       2
# Aronsson             1
#                     ..
# Wilhelms             1
# Wilkes               1
# Willard              1
# Willer               1
# Willey               1
# Williams             5
# Williams-Lambert     1
# Wilson               1
# ...
