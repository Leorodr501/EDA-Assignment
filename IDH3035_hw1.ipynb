# %% [markdown]
# <a href="https://colab.research.google.com/github/Leorodr501/EDA-Assignment/blob/master/IDH3035_hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ruturajshete1008/US-Salary-Data-Analysis-using-R-Programming/master/US_Salary_Data.csv")

# %%
df.head()
# Out:
#          Date  Gold Prices per ounce(USD)  Gold Prices per ounce (Rupees)
# 0  05/25/2016                      1223.5                        82781.39
# 1  05/24/2016                      1228.9                        84162.01
# 2  05/23/2016                      1251.1                        84134.09
# 3  05/20/2016                      1252.4                        84250.75
# 4  05/19/2016                      1254.2                        84815.33

# %%
df
# Out:
#            Date  Gold Prices per ounce(USD)  Gold Prices per ounce (Rupees)
# 0    05/25/2016                      1223.5                        82781.39
# 1    05/24/2016                      1228.9                        84162.01
# 2    05/23/2016                      1251.1                        84134.09
# 3    05/20/2016                      1252.4                        84250.75
# 4    05/19/2016                      1254.2                        84815.33
# 5    05/18/2016                      1273.7                        85167.28
# 6    05/17/2016                      1276.2                        85045.95
# 7    05/16/2016                      1273.4                        85230.50
# 8    05/13/2016                      1271.9                        84887.76
# 9    05/12/2016                      1270.3                        84726.45
# 10   05/11/2016                      1274.6                        84769.26
# ...

# %%
len(df)
# Out:
# 167

# %%
np.mean(df['USD_Gold'])
# Out:
# 1169.7155688622752

# %%
np.std(df['USD_Gold'])
# Out:
# 76.66948895130083

# %%
np.min(df['USD_Gold'])
# Out:
# 1050.8

# %%
np.max(df['USD_Gold'])
# Out:
# 1294.7

# %%
np.mean(df['Rupees_Gold']), np.std(df['Rupees_Gold']), np.min(df['Rupees_Gold']), np.max(df['Rupees_Gold'])
# Out:
# (77900.97107784427, 5078.1034915617865, 70320.03, 85899.69)

# %%
df.columns = ['Date', 'USD_Gold', 'Rupees_Gold']

# %%
df.columns
# Out:
# Index(['Date', 'USD_Gold', 'Rupees_Gold'], dtype='object')

# %%
df
# Out:
#            Date  USD_Gold  Rupees_Gold
# 0    05/25/2016    1223.5     82781.39
# 1    05/24/2016    1228.9     84162.01
# 2    05/23/2016    1251.1     84134.09
# 3    05/20/2016    1252.4     84250.75
# 4    05/19/2016    1254.2     84815.33
# 5    05/18/2016    1273.7     85167.28
# 6    05/17/2016    1276.2     85045.95
# 7    05/16/2016    1273.4     85230.50
# 8    05/13/2016    1271.9     84887.76
# 9    05/12/2016    1270.3     84726.45
# 10   05/11/2016    1274.6     84769.26
# 11   05/10/2016    1263.9     84474.71
# 12   05/09/2016    1265.6     85660.00
# 13   05/06/2016    1292.9     85390.96
# 14   05/05/2016    1271.4     85391.25
# 15   05/04/2016    1273.3     85473.88
# 16   05/03/2016    1290.7     85856.89
# 17   05/02/2016    1294.7     85899.69
# 18   04/29/2016    1289.2     84337.92
# 19   04/28/2016    1265.5     83207.06
# 20   04/27/2016    1249.2     82912.51
# 21   04/26/2016    1242.2     83029.02
# 22   04/25/2016    1238.9     82476.49
# ...
